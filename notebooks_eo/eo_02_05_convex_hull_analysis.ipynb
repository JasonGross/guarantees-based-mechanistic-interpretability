# %% [markdown]
# LaTeX macros
# $$
# \newcommand{\f}[2]{\frac{#1}{#2}}
# \newcommand{\at}[]{\Bigr|}
# \newcommand{\im}[]{\mathop{\text{im}}}
# \newcommand{\ker}[]{\mathop{\text{ker}}}
# \newcommand{\span}[]{\mathop{\text{span}}}
# \newcommand{\actson}[]{\mathop{↷}}
# \newcommand{\stab}[]{\mathop{\text{Stab}}}
# \newcommand{\vv}[1]{\mathbf{#1}}
# \newcommand{\Q}[]{\mathbb{Q}}
# \newcommand{\B}[]{\mathbb{B}}
# \newcommand{\L}[]{\mathbb{L}}
# \newcommand{\Z}[]{\mathbb{Z}}
# \newcommand{\V}[]{\mathbb{V}}
# \newcommand{\X}[]{\mathbb{X}}
# \newcommand{\C}[]{\mathbb{C}}
# \newcommand{\eps}[]{\varepsilon}
# \newcommand{\true}[]{\textbf{true}}
# \newcommand{\false}[]{\textbf{false}}
# \newcommand{\skip}[]{\textbf{skip}}
# \newcommand{\ite}[3]{\textbf{if }#1\textbf{ then }#2\textbf{ else }#3}
# \newcommand{\while}[2]{\textbf{while }#1\textbf{ do }#2}
# \newcommand{\tb}[1]{\textbf{#1}}
# \newcommand{\abr}[1]{\left\langle #1 \right\rangle}
# \newcommand{\br}[1]{\left( #1 \right)}
# \newcommand{\dv}[2]{\frac{d #1}{d #2}}
# \newcommand{\pdv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\lik}[]{\mathop{\text{lik}}}
# \newcommand{\pdf}[]{\text{pdf}}
# \newcommand{\pp}[]{\mathbb{P}}
# \newcommand{\cvvv}[3]{\begin{pmatrix} #1 \\ #2 \\ #3 \end{pmatrix}}
# \newcommand{\cvv}[2]{\begin{pmatrix} #1 \\ #2 \end{pmatrix}}
# \newcommand{\mat}[4]{\begin{bmatrix} #1 & #2 \\ #3 & #4 \end{bmatrix}}
# \newcommand{\Pr}[]{\mathop{\rm{Pr}}}
# \newcommand{\config}[]{\text{Config}}
# \newcommand{\dom}[]{\mathop{\text{dom}}}
# \newcommand{\ran}[]{\mathop{\text{ran}}}
# \newcommand{\intref}[]{\mathop{\text{intref}}}
# \newcommand{\typeenv}[]{\mathop{\text{TypeEnv}}}
# \newcommand{\store}[]{\text{store}}
# \newcommand{\fn}[2]{\textbf{fn }#1\ldotp#2}
# \newcommand{\let}[2]{\textbf{let val } #1 \textbf{ in } #2 \textbf{ end}}
# \newcommand{\letrec}[4]{\textbf{let val rec } #1 = \fn{#2}{#3} \textbf{ in } #4 \textbf{ end}}
# \newcommand{\inl}[]{\mathop{\textbf{inl}}}
# \newcommand{\inr}[]{\mathop{\textbf{inr}}}
# \newcommand{\conc}[]{\mathop{\Vert}}
# \newcommand{\aabr}[1]{\left\langle\negthinspace\left\langle #1\right\rangle\negthinspace\right\rangle}
# \newcommand{\cbr}[1]{\left\{ #1 \right\}}
# \newcommand{\sbr}[1]{\llbracket #1 \rrbracket}
# \newcommand{\sqbr}[1]{\left[ #1 \right]}
# \newcommand{\abs}[1]{\left| #1 \right|}
# \newcommand{\lonepar}[]{L_{1\mid}}
# \newcommand{\lock}[1]{\textbf{lock }#1}
# \newcommand{\unlock}[1]{\textbf{unlock }#1}
# \newcommand{\oto}[1]{\overset{#1}{\longrightarrow}}
# \newcommand{\cN}[]{\mathcal{N}}
# \newcommand{\halts}[]{\downarrow}
# \newcommand{\defined}[]{\downarrow}
# \newcommand{\undefined}[]{\uparrow}
# \newcommand{\if}[]{\text{ if }}
# \newcommand{\otherwise}[]{\text{ otherwise }}
# \newcommand{\halt}[]{\texttt{HALT}}
# \newcommand{\partialto}[]{\rightharpoonup}
# \newcommand{\entails}[]{\vDash}
# \newcommand{\qquote}[1]{\ulcorner #1 \urcorner}
# \newcommand{\tto}[]{\Rightarrow}
# \newcommand{\mbt}[]{\mathbf{t}}
# \newcommand{\mbf}[]{\mathbf{f}}
# \newcommand{\siff}[]{\leftrightarrow}
# \newcommand{\cA}[]{\mathcal{A}}
# \newcommand{\cB}[]{\mathcal{B}}
# \newcommand{\cC}[]{\mathcal{C}}
# \newcommand{\cD}[]{\mathcal{D}}
# \newcommand{\cE}[]{\mathcal{E}}
# \newcommand{\cF}[]{\mathcal{F}}
# \newcommand{\cG}[]{\mathcal{G}}
# \newcommand{\cH}[]{\mathcal{H}}
# \newcommand{\cI}[]{\mathcal{I}}
# \newcommand{\cJ}[]{\mathcal{J}}
# \newcommand{\cK}[]{\mathcal{K}}
# \newcommand{\cL}[]{\mathcal{L}}
# \newcommand{\cM}[]{\mathcal{M}}
# \newcommand{\cO}[]{\mathcal{O}}
# \newcommand{\cP}[]{\mathcal{P}}
# \newcommand{\cQ}[]{\mathcal{Q}}
# \newcommand{\cR}[]{\mathcal{R}}
# \newcommand{\cS}[]{\mathcal{S}}
# \newcommand{\cT}[]{\mathcal{T}}
# \newcommand{\cU}[]{\mathcal{U}}
# \newcommand{\cV}[]{\mathcal{V}}
# \newcommand{\cW}[]{\mathcal{W}}
# \newcommand{\cX}[]{\mathcal{X}}
# \newcommand{\cY}[]{\mathcal{Y}}
# \newcommand{\cZ}[]{\mathcal{Z}}
# \newcommand{\bA}[]{\mathbb{A}}
# \newcommand{\bB}[]{\mathbb{B}}
# \newcommand{\bC}[]{\mathbb{C}}
# \newcommand{\bD}[]{\mathbb{D}}
# \newcommand{\bE}[]{\mathbb{E}}
# \newcommand{\bF}[]{\mathbb{F}}
# \newcommand{\bG}[]{\mathbb{G}}
# \newcommand{\bH}[]{\mathbb{H}}
# \newcommand{\bI}[]{\mathbb{I}}
# \newcommand{\bJ}[]{\mathbb{J}}
# \newcommand{\bK}[]{\mathbb{K}}
# \newcommand{\bL}[]{\mathbb{L}}
# \newcommand{\bM}[]{\mathbb{M}}
# \newcommand{\bN}[]{\mathbb{N}}
# \newcommand{\bO}[]{\mathbb{O}}
# \newcommand{\bP}[]{\mathbb{P}}
# \newcommand{\bQ}[]{\mathbb{Q}}
# \newcommand{\bR}[]{\mathbb{R}}
# \newcommand{\bS}[]{\mathbb{S}}
# \newcommand{\bT}[]{\mathbb{T}}
# \newcommand{\bU}[]{\mathbb{U}}
# \newcommand{\bV}[]{\mathbb{V}}
# \newcommand{\bW}[]{\mathbb{W}}
# \newcommand{\bX}[]{\mathbb{X}}
# \newcommand{\bY}[]{\mathbb{Y}}
# \newcommand{\bZ}[]{\mathbb{Z}}
# \newcommand{\proj}[]{\text{proj}}
# \newcommand{\zero}[]{\text{zero}}
# \newcommand{\succ}[]{\text{succ}}
# \newcommand{\lto}[]{\leftarrow}
# \newcommand{\pto}[]{\rightharpoonup}
# \newcommand{\leftem}[]{\triangleright}
# \newcommand{\mbeta}[]{\twoheadrightarrow}
# \newcommand{\lmbeta}[]{\twoheadleftarrow}
# \newcommand{\epsclosure}[1]{\varepsilon\text{-} closure(#1)}
# \newcommand{\TIME}[]{\mathsf{TIME}}
# \newcommand{\SPACE}[]{\mathsf{SPACE}}
# \newcommand{\PTIME}[]{\mathsf{P}}
# \newcommand{\NPTIME}[]{\mathsf{NP}}
# \newcommand{\coNPTIME}[]{\textsf{co-NP}}
# \newcommand{\obj}[]{\mathop{\texttt{obj}}}
# \newcommand{\id}[]{\mathop{\texttt{id}}}
# \newcommand{\istrue}[1]{#1\text{ true}}
# \newcommand{\istype}[1]{#1\text{ type}}
# \newcommand{\type}[]{\mathop{\,\text{type}}}
# \newcommand{\ctx}[]{\mathop{\,\text{ctx}}}
# \newcommand{\list}[1]{\texttt{List}\,#1}
# \newcommand{\nil}[]{\texttt{nil}}
# \newcommand{\yo}[]{\text{y}}
# \newcommand{\seq}[]{\sqsubseteq}
# \newcommand{\lub}[]{\bigsqcup}
# \newcommand{\enc}[]{\textsf{Enc}}
# \newcommand{\dec}[]{\textsf{Dec}}
# \newcommand{\gen}[]{\mathsf{Gen}}
# \newcommand{\mac}[]{\mathsf{Mac}}
# \newcommand{\vrfy}[]{\mathsf{Vrfy}}
# \newcommand{\F}[]{\mathbb{F}}
# \newcommand{\concat}[]{\mathop{||}}
# \newcommand{\PP}[]{\mathbf{P}}
# \newcommand{\EE}[]{\mathbb{E}}
# \newcommand{\EEwrt}[1]{\underset{#1}{\mathbb{E}}}
# \newcommand{\sgn}[]{\text{sgn}}
# \newcommand{\sneg}[]{\mathop{\sim}}
# \newcommand{\null}[]{\text{null}}
# \newcommand{\fail}[]{\text{↯}}
# \newcommand{\head}[]{\text{HEAD}}
# \newcommand{\doubleplus}[]{\mathop{\text{⧺}}}
# \newcommand{\bigstep}[]{\Downarrow}
# \newcommand{\dlog}[]{\textsf{DLog}}
# \newcommand{\ts}[1]{\textsf{#1}}
# \newcommand{\tc}[1]{\texttt{#1}}
# \newcommand{\complexity}[2]{{\color{darkred}\underbrace{{\color{black}#2}}_{#1}}}
# \newcommand{\argmin}[]{\mathop{\arg\min}}
# $$

# %% [markdown]
# > **Problem:** Given a list of 10 integers from 0 to 63 inclusive, find the maximum integer.

# %% [markdown]
# # Setup

# %%
import torch
from torch import tensor

from gbmi.exp_max_of_n.train import MAX_OF_10_CONFIG
from gbmi.model import train_or_load_model
import gbmi.utils as utils

import gbmi.analysis_tools.l1h1 as l1h1
import gbmi.analysis_tools.plot as plot
import gbmi.analysis_tools.decomp as decomp
import gbmi.analysis_tools.fit as fit
import gbmi.exp_max_of_n.analysis as exp_utils

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from gbmi.utils.pretty import pprint

# %%
config = MAX_OF_10_CONFIG
pprint(config)
# Out:
# Config(
#     experiment=MaxOfN(
#         model_config=HookedTransformerConfig(
#             n_layers=1,
#             d_model=32,
#             n_ctx=10,
#             d_head=32,
#             n_heads=1,
#             d_vocab=64,
#             normalization_type=None,
#             device=device(type='mps'),
#             attn_only=True,
#             seed=613947648,
#             initializer_range=float64(0.1414213562373095),
#             d_vocab_out=64,
#             n_params=4096
#         ),
#         seq_len=10,
#         logging_options=ModelMatrixLoggingOptions(qpos=-1)
#     ),
#     validation_batch_size=128,
#     train_for=(50000, 'steps'),
#     validate_every=None
# )

# %%
rundata, model = train_or_load_model(config)
model.to("cpu")
# Out:
# Seed set to 123
# wandb:   1 of 1 files downloaded.
# Moving model to device:  cpu
# HookedTransformer(
#   (embed): Embed()
#   (hook_embed): HookPoint()
#   (pos_embed): PosEmbed()
#   (hook_pos_embed): HookPoint()
#   (blocks): ModuleList(
#     (0): TransformerBlock(
#       (ln1): Identity()
#       (attn): Attention(
#         (hook_k): HookPoint()
#         (hook_q): HookPoint()
#         (hook_v): HookPoint()
#         (hook_z): HookPoint()
#         (hook_attn_scores): HookPoint()
#         (hook_pattern): HookPoint()
#         (hook_result): HookPoint()
#       )
#       (hook_attn_in): HookPoint()
#       (hook_q_input): HookPoint()
#       (hook_k_input): HookPoint()
#       (hook_v_input): HookPoint()
#       (hook_mlp_in): HookPoint()
#       (hook_attn_out): HookPoint()
#       (hook_mlp_out): HookPoint()
#       (hook_resid_pre): HookPoint()
#       (hook_resid_post): HookPoint()
#     )
#   )
#   (unembed): Unembed()
# )

# %%
rundata.test_metrics
# Out:
# [{'test_loss': 6.139447577879764e-06, 'test_acc': 1.0}]

# %%
config_w = utils.set_params(
    MAX_OF_10_CONFIG,
    {
        ("experiment", "optimizer_kwargs", "weight_decay"): 1e-3,
        # ("experiment", "model_config", "d_head"): 3,
    },
)
pprint(config_w)
# Out:
# Config(
#     experiment=MaxOfN(
#         model_config=HookedTransformerConfig(
#             n_layers=1,
#             d_model=32,
#             n_ctx=10,
#             d_head=32,
#             n_heads=1,
#             d_vocab=64,
#             normalization_type=None,
#             device='cpu',
#             attn_only=True,
#             seed=613947648,
#             initializer_range=float64(0.1414213562373095),
#             d_vocab_out=64,
#             n_params=4096
#         ),
#         seq_len=10,
#         logging_options=ModelMatrixLoggingOptions(qpos=-1),
#         optimizer_kwargs={
#             'lr': 0.001,
#             'betas': (0.9, 0.999),
#             'weight_decay': 0.001
#         }
#     ),
#     validation_batch_size=128,
#     train_for=(50000, 'steps'),
#     validate_every=None
# )

# %%
model
# Out:
# HookedTransformer(
#   (embed): Embed()
#   (hook_embed): HookPoint()
#   (pos_embed): PosEmbed()
#   (hook_pos_embed): HookPoint()
#   (blocks): ModuleList(
#     (0): TransformerBlock(
#       (ln1): Identity()
#       (attn): Attention(
#         (hook_k): HookPoint()
#         (hook_q): HookPoint()
#         (hook_v): HookPoint()
#         (hook_z): HookPoint()
#         (hook_attn_scores): HookPoint()
#         (hook_pattern): HookPoint()
#         (hook_result): HookPoint()
#       )
#       (hook_attn_in): HookPoint()
#       (hook_q_input): HookPoint()
#       (hook_k_input): HookPoint()
#       (hook_v_input): HookPoint()
#       (hook_mlp_in): HookPoint()
#       (hook_attn_out): HookPoint()
#       (hook_mlp_out): HookPoint()
#       (hook_resid_pre): HookPoint()
#       (hook_resid_post): HookPoint()
#     )
#   )
#   (unembed): Unembed()
# )

# %%
rundata, model = train_or_load_model(config_w)
model.to("cpu")
# Out:
# Seed set to 123
# wandb:   1 of 1 files downloaded.
# Moving model to device:  cpu
# HookedTransformer(
#   (embed): Embed()
#   (hook_embed): HookPoint()
#   (pos_embed): PosEmbed()
#   (hook_pos_embed): HookPoint()
#   (blocks): ModuleList(
#     (0): TransformerBlock(
#       (ln1): Identity()
#       (attn): Attention(
#         (hook_k): HookPoint()
#         (hook_q): HookPoint()
#         (hook_v): HookPoint()
#         (hook_z): HookPoint()
#         (hook_attn_scores): HookPoint()
#         (hook_pattern): HookPoint()
#         (hook_result): HookPoint()
#       )
#       (hook_attn_in): HookPoint()
#       (hook_q_input): HookPoint()
#       (hook_k_input): HookPoint()
#       (hook_v_input): HookPoint()
#       (hook_mlp_in): HookPoint()
#       (hook_attn_out): HookPoint()
#       (hook_mlp_out): HookPoint()
#       (hook_resid_pre): HookPoint()
#       (hook_resid_post): HookPoint()
#     )
#   )
#   (unembed): Unembed()
# )

# %% [markdown]
# # Empirical tests

# %% [markdown]
# > Pass a sample from the dataloader through the model to check it works.

# %%
# dm = config.experiment.get_datamodule()(config)
# dm.setup("fit")

# from tqdm import tqdm
# maxes = set()
# for i in tqdm(dm.data_train):
#     maxes.add(i.max().item())

# t = next(iter(dm.train_dataloader()))

# (t.max(dim=-1).values == model(t).argmax(dim=-1)[:,-1]).float().mean()

# %% [markdown]
# Seems to work.

# %% [markdown]
# > What if we give 'all the same token' as input?

# %%
for i in range(config.experiment.model_config.d_vocab):
    result = model(tensor([[i] * 10])).argmax(dim=-1)[0, 0].item()
    print(i, result, i == result)
# Out:
# 0 37 False
# 1 37 False
# 2 37 False
# 3 43 False
# 4 37 False
# 5 37 False
# 6 37 False
# 7 37 False
# 8 37 False
# 9 37 False
# 10 43 False
# 11 37 False
# 12 37 False
# 13 37 False
# 14 43 False
# 15 37 False
# 16 43 False
# 17 37 False
# 18 37 False
# 19 37 False
# 20 43 False
# 21 37 False
# 22 43 False
# 23 37 False
# 24 37 False
# 25 43 False
# 26 37 False
# 27 43 False
# 28 43 False
# 29 43 False
# 30 37 False
# 31 37 False
# 32 37 False
# 33 37 False
# 34 43 False
# 35 37 False
# 36 43 False
# 37 37 True
# 38 38 True
# 39 39 True
# 40 40 True
# 41 41 True
# 42 42 True
# 43 43 True
# 44 44 True
# 45 45 True
# 46 46 True
# 47 47 True
# 48 48 True
# 49 49 True
# 50 50 True
# 51 51 True
# 52 52 True
# 53 53 True
# 54 54 True
# 55 55 True
# 56 56 True
# 57 57 True
# 58 58 True
# 59 59 True
# 60 60 True
# 61 61 True
# 62 62 True
# 63 63 True

# %% [markdown]
# We fail on sequences `[i,...,i]` for $i \leq 20$.

# %% [markdown]
# # Introducing the model

# %%
from gbmi.utils import ein
from math import sqrt
from torch import exp

U, e, p, Q, K, V, O = [
    i.squeeze().clone().detach()
    for i in [
        model.W_U,
        model.W_E,
        model.W_pos,
        model.W_Q,
        model.W_K,
        model.W_V,
        model.W_O,
    ]
]
d_head = model.cfg.d_head
d = sqrt(d_head)

s = torch.tensor([31, 30, 32, 33, 34, 35, 39, 37, 38, 36])
n = len(s)

# %% [markdown]
# > **NOTE:** We're using right-multiplication of matrices (i.e. $\vv{v}$ is a row-vector by default), and zero-based indexing.

# %% [markdown]
# Consider a 1-layer attention-only transformer, consuming a sequence of $n$ input tokens $(s_0,...,s_{n-1})$, with
# - hidden dimension $h$
# - head dimension $d_{head}$
# - vocabulary size $v$ (representing numbers 0 to $v-1$ with token indices 0 to $v-1$)
#
# Let $d = \sqrt{d_{head}}$, $\vv{e}_t = (W_E)_t$, and $\vv{p}_i = (W_{pos})_i$.

# %% [markdown]
# Then the unnormalised attention from position $n-1$ (storing token $s_{n-1}$) to position $i_q$ (storing token $s_{i_q}$) is given by
# $$\alpha(s_{n-1}, s_{i_q}, i_q) = \f{1}{d} (\vv{e}_{s_{n-1}} + \vv{p}_{n-1}) Q K^T (\vv{e}_{s_{i_q}} + \vv{p}_{i_q})^T$$

# %%
α = ein.array(
    lambda s_n1, s_i_q, i_q: (1 / d)
    * (e[s_n1] + p[n - 1])
    @ Q
    @ K.T
    @ (e[s_i_q] + p[i_q]).T
)
# Out:
# /var/folders/y1/33lbjdps12lf6x0csm_rvb5m0000gn/T/ipykernel_27231/36459535.py:6: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3641.)
#   @ (e[s_i_q] + p[i_q]).T

# %% [markdown]
# and the output logit vector (at position ${n-1}$) is given by
# $$\vv{y}(\vv{s}) = \f{1}{\sum_{i=0}^{{n-1}} e^{\alpha(s_{n-1}, s_i, i)}}
# \left[\sum_{i=0}^{n-1} e^{\alpha(s_{{n-1}}, s_i, i)} (\vv{e}_{s_i} + \vv{p}_i)VOU\right]
# + (\vv{e}_{s_{n-1}} + \vv{p}_{n-1})U$$
# such that $y_i(\vv{s})$ corresponds to the output logit for token $i\in \cbr{0, ...,v-1}$.

# %%
y = lambda s: (
    (
        1
        / ein.sum(lambda i: exp(α[s[n - 1], s[i], i]))
        * ein.sum(lambda i: exp(α[s[n - 1], s[i], i]) * (e[s[i]] + p[i]) @ V @ O @ U)
    )
    + (e[s[n - 1]] + p[n - 1]) @ U
)
true_logits = model(torch.tensor(s))
assert torch.allclose(y(torch.tensor(s)), true_logits.squeeze()[-1], atol=1e-5)
# Out:
# /var/folders/y1/33lbjdps12lf6x0csm_rvb5m0000gn/T/ipykernel_27231/1627245852.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   true_logits = model(torch.tensor(s))
# /var/folders/y1/33lbjdps12lf6x0csm_rvb5m0000gn/T/ipykernel_27231/1627245852.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   assert torch.allclose(y(torch.tensor(s)), true_logits.squeeze()[-1], atol=1e-5)

# %% [markdown]
# Alternatively, we can write $y_t(\vv{s})$ in terms of
#
# - the _residual logit contribution for $t$ from position $n-1$ (with value $s_{n}$)_:
#
# $$r(t, s_{{n-1}}) = [(\vv{e}_{s_{{n-1}}} + \vv{p}_{{n-1}})U]_t$$
#
# - the _OV logit contribution for $t$ from position $i$ (with value $s_i$)_:
#
# $$v(t, i, s_i) = [(\vv{e}_{s_iz} + \vv{p}_i)VOU]_t$$
#
# as
#
# $$y_t(\vv{s}) = \f{1}{\sum_{i=0}^{{n-1}} e^{\alpha(s_{n-1}, s_i, i)}}
# \left[\sum_{i=0}^{n-1} e^{\alpha(s_{{n-1}}, s_i, i)} v(t, i, s_i)\right]
# + r(t, s_{{n-1}})$$

# %%
r = ein.array(lambda t, s_n1: ((e[s_n1] + p[n - 1]) @ U)[t])
v = ein.array(lambda t, i, s_i: ((e[s_i] + p[i]) @ V @ O @ U)[t])

# %%
y_t = lambda t, s: (
    1
    / ein.sum(lambda i: exp(α[s[n - 1], s[i], i]))
    * ein.sum(lambda i: exp(α[s[n - 1], s[i], i]) * v[t, i, s[i]])
    + r[t, s[n - 1]]
)

# %%
assert torch.allclose(y_t(0, s), true_logits.squeeze()[-1, 0], atol=1e-5)

# %% [markdown]
# # The problem

# %% [markdown]
# We're interested in bounding the _$\eps$-accuracy_ of our transformer over some target set $S\subseteq \cbr{0,...,v-1}^{n}$ -- in other words, the fraction of times the difference between the output logit for token $\max(\vv{s})$ and the next highest output logit is $> \eps$, over sequences $\vv{s}\in S$:
#
# $$\begin{aligned}
# acc_\eps(S) &= \frac{1}{|S|}\sum_{\vv{s}\in S}1[y_{\max(\vv{s})}(\vv{s}) - y_{t}(\vv{s}) > \eps \; \forall t\in \vv{s}]\\
# &= \frac{1}{|S|}\sum_{\vv{s}\in S}1[y_{\max(\vv{s})}(\vv{s}) - \max_{t\in \vv{s}} y_{t}(\vv{s}) - \eps > 0]
# \end{aligned}$$

# %% [markdown]
# # Initial bound

# %% [markdown]
# While naïvely evaluating $acc_\eps(S)$ would take time exponential in the length of our sequence, we can obtain a lower bound on $acc_\eps(S)$ by identifying subsets $U\subseteq S$ of valid sequences $\vv{s}$ (i.e. such that $y_{\max(\vv{s})}(\vv{s}) - \max_{t\in \vv{s}} y_{t}(\vv{s}) - \eps > 0$).
#
# As such, we ask: for tokens $t_1 = \max(\vv{s})$ and arbitrary $t_2$, what conditions on $\vv{s}$ imply $y_{t_1}(\vv{s})-y_{t_2}(\vv{s}) - \eps > 0$?

# %% [markdown]
# Have $$\begin{aligned}
# 0 &\leq y_{t_1}(\vv{s}) - y_{t_2}(\vv{s})-\eps\\
# \iff 0&\leq \f{1}{\sum_{i=0}^{{n-1}} e^{\alpha(s_{n-1}, s_i, i)}}
# \left[\sum_{i=0}^{n-1} e^{\alpha(s_{{n-1}}, s_i, i)} (v(t_1, i, s_i) - v(t_2, i, s_i))\right] \\
# &+ r(t_1, s_{n-1}) - r(t_2, s_{n-1})-\eps\\
# \iff 0 &\leq \sum_{i=0}^{n-1} e^{\alpha(s_{{n-1}}, s_i, i)} [v(t_1, i, s_i) - v(t_2, i, s_i)] \\
# &+ \sum_{i=0}^{{n-1}} e^{\alpha(s_{n-1}, s_i, i)} [r(t_1, s_{n-1}) - r(t_2, s_{n-1})-\eps]\\
# \iff 0 &\leq \sum_{i=0}^{n-1} e^{\alpha(s_{{n-1}}, s_i, i)} [v(t_1, i, s_i) - v(t_2, i, s_i) +
#  r(t_1, s_{n-1}) - r(t_2, s_{n-1})-\eps] = \sum_{i=0}^{n-1} \Delta_\eps^{(1)}(t_1, t_2, i, s_i, s_{n-1})
# \end{aligned}$$

# %% [markdown]
# > Intuitively, $\Delta_\eps^{(1)}$ is the contribution to the logit difference $y_{t_1}(\vv{s}) - y_{t_2}(\vv{s})$ due to attending to position $i$.

# %% [markdown]
# Now, pessimising over the position index $i$ of the query token, have
# $$\begin{aligned}
# \impliedby 0 &\leq \sum_{i=0}^{n-1} \min_{j\in P} \left( e^{\alpha(s_{{n-1}}, s_i, j)} [v(t_1, j, s_i) - v(t_2, j, s_i) +
#  r(t_1, s_{n-1}) - r(t_2, s_{n-1})-\eps]\right) = \sum_{i=0}^{n-1} \Delta_\eps^{(2)}(t_1, t_2, s_i, s_{n-1}) \\
# \end{aligned}$$

# %% [markdown]
# And pessimising over the token value $s_{n-1}$ (which must be $\leq t_1 = \max(\vv{s})$), have
# $$\begin{aligned}
# \impliedby 0 &\leq \sum_{i=0}^{n-1} \min_{j\in P, s_{n-1}\leq t_1} \left( e^{\alpha(s_{{n-1}}, s_i, j)} [v(t_1, j, s_i) - v(t_2, j, s_i) +
#  r(t_1, s_{n-1}) - r(t_2, s_{n-1})-\eps]\right) = \sum_{i=0}^{n-1} \Delta_\eps^{(3)}(t_1, t_2, s_i) \\
# \end{aligned}$$

# %% [markdown]
# Now, since $\Delta_\eps^{(3)}$ is invariant to permutations of $\vv{s}$, suppose $\vv{s}$ contains $\#_x(\vv{s})$ copies of token $x$. Then have
#
# $$\begin{aligned}
# \impliedby 0 &\leq \sum_{s=0}^{|V|-1} \#_s(\vv{s}) \Delta_\eps^{(3)}(t_1, t_2, s)\\
# \impliedby 0 &\leq (n-1) \min_{s\in \vv{s}} \Delta_\eps^{(3)}(t_1, t_2, s)+ \Delta_\eps^{(3)}(t_1, t_2, \max(\vv{s}))\\
# \end{aligned}$$
#
# by convexity.
#
# ---

# %% [markdown]
# A sequence $\vv{s}$ is correctly recognised (with logit gap $\eps$) if
#
# $$\begin{aligned}
# 0 &\leq \min_{t_{attn}\in \vv{s}, t_{cmp}\in V} \sqbr{(n-1)\Delta_\eps^{(3)}(\max(\vv{s}), t_{cmp}, t_{attn}) + \Delta_\eps^{(3)}(\max(\vv{s}), t_{cmp}, \max(\vv{s}))}\\
# \impliedby 0 &\leq \min_{t_{attn}\in \vv{s}} \sqbr{(n-1)\Delta_\eps^{(3)}(\max(\vv{s}), t_{cmp}, t_{attn}) + \Delta_\eps^{(3)}(\max(\vv{s}), t_{cmp}, \max(\vv{s}))}=\min_{t_{attn}\in \vv{s}} \Delta_\eps^{(4)}(\max(\vv{s}), t_{attn})\\
# \end{aligned}$$

# %% [markdown]
# Hence, for tokens $t_{max}$, $t_{attn}$, if
#
# $$0 \leq \Delta_\eps^{(4)}(t_{max}, t_{attn}) $$
#
# then our model correctly recognises all sequences $\vv{s}$ for which
# - $t_{max}=\max(\vv{s})$, and
# - $t_{attn}\in \vv{s}$ is the element for which $\Delta_\eps^{(4)}(t_{max}, t_{attn})$ is minimised
#
# ---

# %% [markdown]
# ## Computing the bound

# %%
from gbmi.utils import ein
from torch import where

# %% [markdown]
# To count the number of sequences, we first precompute
#
# $$\boxed{
# \begin{aligned}
# \alpha(\complexity{O(nv^2)}{s_{n-1}, s_{i_q}, i_q}) &= \complexity{O(h^2)}{\f{1}{d} (\vv{e}_{s_{n-1}} + \vv{p}_{n-1}) Q K^T (\vv{e}_{s_{i_q}} + \vv{p}_{i_q})^T}\\
# r(\complexity{O(v)}{t, s_{{n-1}}}) &= \complexity{O(hv)}{[(\vv{e}_{s_{{n-1}}} + \vv{p}_{{n-1}})U]_t}\\
# v(\complexity{O(nv)}{t, i, s_i}) &= \complexity{O(h^2+hv)}{[(\vv{e}_{s_i} + \vv{p}_i)VOU]_t}\\
# \Delta_\eps^{(3)}(\complexity{O(v^3)}{t_1, t_2, s_i}) &= \complexity{O(nv)}{\min_{j\in P, s_{n-1}\leq t_1} \left( e^{\alpha(s_{{n-1}}, s_i, j)} [v(t_1, j, s_i) - v(t_2, j, s_i) +
#  r(t_1, s_{n-1}) - r(t_2, s_{n-1})-\eps]\right)}\\
# \Delta_\eps^{(4)}(\complexity{O(v^2)}{\max(\vv{s}), t_{attn}}) &= \complexity{O(v)}{\min_{t_{cmp}\in V} \sqbr{(n-1)\Delta_\eps^{(3)}(\max(\vv{s}), t_{cmp}, t_{attn}) + \Delta_\eps^{(3)}(\max(\vv{s}), t_{cmp}, \max(\vv{s}))}}
# \end{aligned}}$$
#
# with time complexity $\color{darkred}O(nv^2h^2 + nv^4)$.

# %%
ϵ = 0
Δ_ϵ_3 = ein.array(
    lambda t_1, t_2, s_i: ein.min(
        lambda j, s_n1: where(
            (s_n1 <= t_1),
            exp(α[s_n1, s_i, j])
            * (v[t_1, j, s_i] - v[t_2, j, s_i] + r[t_1, s_n1] - r[t_2, s_n1] - ϵ),
            1e13,
        ),
        sizes=[α.shape[2], α.shape[0]],
    ),
    sizes=[r.shape[0], r.shape[0], α.shape[1]],
)

# %%
Δ_ϵ_4 = ein.array(
    lambda max_s, t_attn: ein.min(
        lambda t_cmp: (n - 1) * Δ_ϵ_3[max_s, t_cmp, t_attn] + Δ_ϵ_3[max_s, t_cmp, max_s]
    ),
)

# %% [markdown]
# ---

# %% [markdown]
# Now, to find the number of possible sequences with a given maximum element $t_{max}$, note that any such sequence must contain at least one instance of $t_{max}$, with all other elements being chosen from a set of size
#
# $$c(t_{max}) = \max\br{0, t_{max} + 1 - \min\cbr{t_{attn} \in V \mid 0 \leq \Delta_\eps^{(4)}(t_{max}, t_{attn}) \land t_{attn} \leq t_{max}}}$$
#
# (containing $t_{max}$).
#
# So, by considering all possible sequences with $c(t_{max})$ elements and discounting those not containing $t_{max}$, we have a total of
#
# $$c(t_{max})^n - (c(t_{max})-1)^n$$
#
# possible sequences.
#
# In total, this part of the computation has time complexity $\color{darkred}O(v^2)$.

# %%
c = ein.array(
    lambda t_max: torch.maximum(
        torch.tensor(0),
        -ein.min(
            lambda t_attn: where(
                (0 <= Δ_ϵ_4[t_max, t_attn]) & (t_attn <= t_max), t_attn, 1e9
            )
        )
        + t_max
        + 1,
    ),
)

# %% [markdown]
# ---
# We can now compute the lower bound:

# %%
torch.maximum(c**10 - (c - 1) ** 10, torch.tensor(0)).sum() / (U.shape[-1] ** 10)
# Out:
# tensor(0.9968)

# %% [markdown]
# Overall, this lower bound has time complexity $\color{darkred}O(nv^2h^2 + nv^4)$.

# %% [markdown]
# ## Discussion

# %% [markdown]
# This seems very high! But for a bit more granularity, we can plot (a lower bound on) the set of tokens $s\in \max(\vv{s})$ compatible with $\max(\vv{s})$ for different values of $\max(\vv{s})$.

# %%
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'svg'
plt.rcParams["figure.dpi"] = 150

plt.figure(figsize=(7, 5))
plt.plot(c, marker=".", label="Lower bound on # tokens")
plt.plot(torch.arange(0, 64), torch.arange(1, 65), label="Maximum # tokens")

plt.title(
    "Lower bound on # tokens $s\leq \max({\mathbf{s}})$ compatible with $\max({\mathbf{s}})$"
)
plt.legend(loc="best")
plt.xlabel("Maximum element $\max({\mathbf{s}})$")
plt.ylabel("# tokens")
plt.grid(which="both")
plt.minorticks_on()
plt.ylim(ymin=0, ymax=65)
plt.xlim(xmin=0, xmax=64)
plt.show()
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %% [markdown]
# Observe that, while our lower bound on accuracy for sequences with $\max(\mathbf{s}) < 30$ is ~0, we still get an extremely high lower bound for the overall problem, because sequences with $\max(\mathbf{s}) < 30$ make up such a small fraction of the overall distribution:

# %%
num_seqs_with_max = lambda m: (m + 1) ** n - m**n

# %%
num_seqs_with_max_leq = lambda m: m**n

# %%
num_seqs_with_max_leq(29) / num_seqs_with_max_leq(63)
# Out:
# 0.00042714417128587347

# %%
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'svg'
plt.rcParams["figure.dpi"] = 150

plt.figure(figsize=(7, 5))
plt.plot(
    [
        max(num_seqs_with_max(int(i) - 1), 0) / num_seqs_with_max(z)
        for z, i in enumerate(c)
    ],
    marker=".",
)

plt.title("Lower bound on accuracy over values of $\max(\mathbf{s})$")
plt.legend(loc="best")
plt.xlabel("Maximum element $\max({\mathbf{s}})$")
plt.ylabel("Lower bound on accuracy")
plt.grid(which="both")
plt.minorticks_on()
# plt.ylim(ymin=0, ymax=65)
plt.xlim(xmin=0, xmax=64)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'svg'
plt.rcParams["figure.dpi"] = 150

plt.figure(figsize=(7, 5))
plt.plot(
    [num_seqs_with_max(int(i) - 1) for i in c],
    marker=".",
    label="Lower bound on # correct sequences",
)
plt.plot([num_seqs_with_max(i) for i in range(64)], label="Maximum # correct sequences")

plt.title("Lower bound on # correct sequences")
plt.legend(loc="best")
plt.xlabel("Maximum element $\max({\mathbf{s}})$")
plt.ylabel("# sequences")
plt.grid(which="both")
plt.minorticks_on()
# plt.ylim(ymin=0, ymax=65)
plt.xlim(xmin=0, xmax=64)
plt.show()

# %% [markdown]
# # OV matrices

# %% [markdown]
# For a weight-decayed model, let's take a look at the copying action.

# %%
import numpy as np


def show_with_max_elt(data):
    # Display the original image
    plt.imshow(data)

    # Get the index of the max-valued pixel in each row
    max_indices = np.argmax(data, axis=1)

    # Get the range of row numbers
    rows = np.arange(data.shape[0])

    # Plot a red dot at the max-valued pixel of each row
    plt.scatter(max_indices, rows, color="red", s=10)  # s is the size of the dot

    # Show the plot with the red dots
    plt.show()

# %%
V.shape
# Out:
# torch.Size([32, 32])

# %%
norm = lambda x: x / torch.sqrt((x**2).sum(-1, keepdim=True))

# %%
x1, y1, z1 = (e @ V).T  # list(norm((e@V)).T)
x2, y2, z2 = O @ U  # list(norm((O@U).T).T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 x1, y1, z1 = (e@V).T#list(norm((e@V)).T)
#       2 x2, y2, z2 = (O@U)#list(norm((O@U).T).T)
#
# ValueError: too many values to unpack (expected 3)

# %%
plt.plot(x1[45:], y1[45:], marker="x")
plt.plot(x2[45:], y2[45:], marker="o")
plt.axis("equal")

plt.show()

# %%
show_with_max_elt(e @ V @ O @ U)

# %%
import plotly.express as px

df = px.data.iris()
fig = px.scatter_3d(
    df, x="sepal_length", y="sepal_width", z="petal_width", color="species"
)
fig.show()

# %%
# %matplotlib widget

# %%
c = np.linspace(0, 1, x1.shape[0] - n)

# %%
plt.figure()
ax = plt.axes(projection="3d")

n = 40

ax.scatter3D(x1[n:], y1[n:], z1[n:], c=c, cmap="RdBu")
ax.scatter3D(x2[n:], y2[n:], z2[n:], c=c, cmap="RdBu")
plt.show()

# %%
v1s = e @ V
v2s = (O @ U).T

# %%
distsv1v1 = ein.array(lambda i, j: torch.sqrt(((v1s[i] - v1s[j]) ** 2).sum(-1)))[
    38:, 38:
]
min_v1v1_dist = ein.array(
    lambda i, j: distsv1v1[i, j] * 0 + where(i == j, 1e9, distsv1v1[i, j])
).min()

# %%
min_v1v1_dist
# Out:
# tensor(3.0497)

# %%
(
    1.0
    * (
        ein.array(lambda i: torch.sqrt(((v1s[i] - v2s[i]) ** 2).sum(-1))) * 2
        < min_v1v1_dist
    )
).mean()
# Out:
# tensor(0.9844)

# %%
max_v1iv2i_dist
# Out:
# tensor(1.7165)

# %%
v1s.shape
# Out:
# torch.Size([64, 32])

# %%
from scipy.spatial import KDTree

# %%
t = KDTree(v1s, leafsize=1)

# %%
t.depth
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 t.depth
#
# AttributeError: 'KDTree' object has no attribute 'depth'

# %% [markdown]
# We roughly preserve the attention pattern if we project onto the unit sphere (which is guaranteed to be convex).

# %%
Unorm = U / torch.linalg.norm(U.T, dim=-1)

eVOnorm = e @ V @ O / torch.linalg.norm((e @ V @ O).T, dim=-1)

show_with_max_elt(eVOnorm @ Unorm)

# %% [markdown]
# ## A toy model of low-rank copying

# %% [markdown]
# Model:
# - Sample points on the unit sphere
# - Add some noise
# - How much noise do we have to add before we lose max-is-identity behaviour?

# %%
b1 = 100
b2 = 1000
n = 64
d = 32
lin = torch.linspace(0, 1, b1)
errors = torch.normal(
    0.0,
    ein.array(
        lambda b, b1, b2, n, d: 0 * b * b1 * b2 * n * d + lin[b1],
        sizes=[2, b1, b2, n, d],
    ),
)
points = torch.normal(0, 1, (b1, b2, n, d))

# %%
normalised = ein.array(
    lambda b1, b2, n_i, d_i: points[b1, b2, n_i, d_i]
    / torch.sqrt(ein.sum(lambda d_j: points[b1, b2, n_i, d_j] ** 2))
)
arr = ein.array(
    lambda b1, b2: (normalised[b1, b2] + errors[0, b1, b2])
    @ (normalised[b1, b2] + errors[1, b1, b2]).T
)

# %%
plt.plot(lin, ((arr.argmax(-1) == torch.arange(n)) * 1.0).mean(dim=-1).mean(dim=-1))
plt.xlabel("Std of error")
plt.ylabel("Argmax accuracy")
plt.show()

# %%
n = 64
d = 32

points = torch.normal(0, 1, (n, d))
normalised = ein.array(
    lambda n_i, d_i: points[n_i, d_i]
    / torch.sqrt(ein.sum(lambda d_j: points[n_i, d_j] ** 2))
)
show_with_max_elt(
    (normalised + torch.normal(0, 0.1, normalised.shape))
    @ (normalised + torch.normal(0, 0.1, normalised.shape)).T
)

# %% [markdown]
# What do the actual norms look like?

# %%
plt.hist(torch.linalg.norm(U.T, dim=-1), bins=10)
plt.hist(torch.linalg.norm((e @ V @ O).T, dim=-1), bins=10)
plt.show()

# %%
plt.hist(torch.linalg.norm(U.T, dim=-1), bins=50)
# plt.hist(torch.linalg.norm((e@V@O).T, dim=-1), bins=10)
plt.show()

# %%
# plt.hist(torch.linalg.norm(U.T, dim=-1), bins=50)
plt.hist(torch.linalg.norm((e @ V @ O).T, dim=-1), bins=50)
plt.show()

# %%
plt.hist(torch.linalg.norm(U.T, dim=-1), bins=50)
# plt.hist(torch.linalg.norm((e@V@O).T, dim=-1), bins=50)
plt.show()

# %%
plt.hist(torch.linalg.norm((O @ U).T, dim=-1), bins=50)
plt.hist(torch.linalg.norm((e @ V).T, dim=-1), bins=50)
plt.show()

# %% [markdown]
# It seems that separating these at eVO / U is meaningful...

# %% [markdown]
# Convex hull intuition: are normalised `eVO` close to normalised `U`?

# %%
(e @ V @ O).shape

# %%
(e @ U).shape

# %%
decomp.pca_2d(
    torch.cat([eVOnorm, Unorm.T]),
    labels=[[f"{i}" for i in range(64)], [f"{i}" for i in range(64)]],
    markers=[0, 4],
)

# %%
decomp.tsne_2d(
    torch.cat([eVOnorm, Unorm.T]),
    labels=[[f"{i}" for i in range(64)], [f"{i}" for i in range(64)]],
    markers=[0, 4],
    perplexity=30,
)

# %% [markdown]
# what margin of error do we have in the original model?

# %%
evou = eVOnorm @ Unorm
maxes = evou.max(dim=-1).values
argmaxes = (evou).argmax(dim=-1)

secondmaxes = (
    ein.array(lambda i, j: where(j == argmaxes[i], -1e9, evou[i, j]), sizes=evou.shape)
    .max(dim=-1)
    .values
)

# %%
plt.plot(maxes - secondmaxes)

# %%
(e @ V @ O @ U).max(dim=-1)

# %%
plt.plot([(e @ V @ O)[i] @ U.T[i] for i in range(64)])

# %%
ein.array(lambda i: torch.sqrt((e @ V @ O)[i] @ (e @ V @ O)[i]))

# %%
normalise = lambda x: x / ein.array(
    lambda i, j: torch.sqrt(x[i] @ x[i]), sizes=[None, 1]
)

# %%
normalise(e @ V @ O)[-5:]

# %%
normalise(U.T)[-5:]

# %% [markdown]
# # Embeddings, QK

# %%
plt.imshow(e)

# %%
plt.imshow(e @ Q)

# %%
plt.imshow(e @ K)

# %%
plt.imshow(Q @ K.T)

# %%
decomp.analyze_svd(Q @ K.T)

# %% [markdown]
# # Playground

# %%
decomp.analyze_svd(Q @ K.T)

# %%
plt.plot((e @ V @ O @ U)[25])

# %%
e @ Q @ K.T @ e.T

# %%
decomp.analyze_svd(e @ Q @ K.T)

# %%
decomp.analyze_svd(K)

# %%
decomp.analyze_svd(Q)

# %% [markdown]
# # Further analysis

# %% [markdown]
# ## OV matrix

# %% [markdown]
# > How does OV of each token affect the output logits?

# %%
l1h1.analyze_EVOU(model)

# %% [markdown]
# > What does positional encoding do?
#
# Seems to add some marginal logit diff (probably not important?) to the output logits... with some banding.

# %%
l1h1.analyze_PVOU(model)

# %%
plot.line((p @ V @ O @ U).squeeze().mean(dim=0), xaxis="token index", yaxis="logit")

# %% [markdown]
# ## QK matrix

# %%
l1h1.analyze_QK(model)

# %%
QK = (e + p[-1]) @ Q[:, :] @ K[:, :].T @ (e + p.mean(dim=0)).T
plot.line(QK.squeeze().mean(dim=0), xaxis="token index", yaxis="attention")

# %% [markdown]
# Attention activation is roughly a monotonically increasing function of key token index (apart from token 43, which fails as we saw before)

# %%
size_direction, query_direction, size_query_singular_value = (
    exp_utils.find_size_and_query_direction(
        model,
        plot_heatmaps=True,
        colorscale="Picnic_r",
        fit_funcs=(fit.quadratic_func, fit.cubic_func, fit.quintic_func),
        delta_fit_funcs=(fit.linear_func, fit.quadratic_func, fit.quartic_func),
    )
)
print(
    f"Size direction: {size_direction}\nQuery direction: {query_direction}\nSingular value: {size_query_singular_value}"
)

# %%
true_logits, cache = model.run_with_cache(torch.tensor(seq))
true_logits = true_logits.squeeze()[-1]
true_max = true_logits.argmax(-1)
print(true_logits)
print(true_max)
